# %% [markdown]
# module
# https://youtu.be/wUSDVGivd-8?t=11570

# %% [markdown]
# library is a collection of modules

# %%
import my_module
my_module.skill_list
my_module.skill
# Out:
# <function my_module.skill(skill_name)>

# %%
my_module.skill("rita")
# Out:
# 'rita is my favourite skill'

# %%
def calculate_salary(base_salary,bonus_rate=.1):
        return base_salary * (1 + bonus_rate)

# %%
import job_analyzer 
job_analyzer.calculate_salary(100000)

# %%
from job_analyzer import calculate_salary, calculate_bonus
# job_analyzer.calculate_salary
print(calculate_salary(10000,.1))
print(calculate_bonus(110000,100000))
# Out:
# 11000.0
# 0.1

# %%
# from job_analyzer import calculate_salary
# calculate_salary(8000)
# Out:
# 8800.0

# %%
from job_analyzer import  calculate_bonus, calculate_salary

# calculate_salary(1100000)
calculate_bonus(1100000,1000000)
# Out:
# 0.1
# 0.1

# %% [markdown]
# https://youtu.be/wUSDVGivd-8?t=12066

# %%
help(calculate_salary)
# Out:
# Help on function calculate_salary in module job_analyzer:
#
# calculate_salary(base_salary, bonus_rate=0.1)

# %%
salary_list = [98000,101000,102000,99000,97000]

# %%
import statistics
statistics.mean(salary_list)
# Out:
# 99400

# %%
from statistics import mean,mode, median


statistics.median(salary_list)
# Out:
# 99000

# %%
statistics.mean(salary_list)
# Out:
# 99400

# %%
statistics.mode(salary_list)
# Out:
# 98000

# %% [markdown]
# ### https://youtu.be/wUSDVGivd-8?t=12496

# %% [markdown]
# ###https://youtu.be/wUSDVGivd-8?t=12508

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 11, 13, 17, 49, 42, 559061)

# %%
data_science_jobs[0]
# Out:
# {'job_title': 'Data Scientist',
#  'job_skills': "['Python', 'SQL', 'Machine Learning']",
#  'job_date': '2023-05-12'}

# %%
from datetime import datetime
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

data_science_jobs[0]['job_skills']
# Out:
# "['Python', 'SQL', 'Machine Learning']"

# %%
from datetime import datetime
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
from datetime import datetime
type(data_science_jobs[0]['job_date'])
# Out:
# str

# %%
from datetime import datetime
test_date=data_science_jobs[0]['job_date']

# %%
from datetime import datetime
test_date = data_science_jobs[0]['job_date']
# datetime.strptime(test_date, '"%Y-%m-%dT%H:%M:%SZ') 
print(test_date)
# Out:
# 2023-05-12

# %%
from datetime import datetime
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

data_science_jobs[0]['job_skills']
# Out:
# "['Python', 'SQL', 'Machine Learning']"

# %%
from datetime import datetime
test_date = (data_science_jobs[0]['job_date'])
datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 5, 12, 0, 0)

# %% [markdown]
# https://youtu.be/wUSDVGivd-8?t=12878

# %%
test_date = data_science_jobs[0]['job_date']
print(test_date)
# Out:
# 2023-05-12
