# %% [markdown]
# module
# https://youtu.be/wUSDVGivd-8?t=11570

# %% [markdown]
# library is a collection of modules

# %%
# In a Jupyter Notebook cell
import my_module

# Now you can use functions and classes from your module
message = my_module.greet("Alice")
print(message)

obj = my_module.MyClass(10)
result = obj.get_value()
print(result)
# Out:
# Hello, Alice!
# 20
