# %%
print(type("Data Analyst"))
print(type(str))
# Out:
# <class 'str'>
# <class 'type'>

# %%
type(str)
# Out:
# type

# %%
bonus_rate = 0.1
base_salary = 10000
total_salary = base_salary*(1 + bonus_rate)
print(total_salary)
# Out:
# 11000.0

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
job_title = "Data Analyst"
job_salary = 90000
my_print_function = print

# %%
my_print_function(job_title, job_salary)
# Out:
# Data Analyst 90000

# %%
id(job_title), id(job_salary), id(my_print_function),
# Out:
# (4608148912, 4607319088, 4516875856)

# %%
lukes_job = job_title

lukes_job
# Out:
# 'Data Analyst'

# %%
def display_info(job_title,job_salary,)

# %%
def display_info(title, location, salary):
    return print(f"JOB:       {title}\nLOCATION:  {location}\nSALARY:    ${salary:,.0f}")

# %%
job_title = "Data Analyst"
job_location = "United States"
job_salary = 90000

display_info(job_title, job_location, job_salary)
# Out:
# JOB:       Data Analyst
# LOCATION:  United States
# SALARY:    $90,000

# %%
class JobPost:
    def __init__(self, title, location, salary):
        self.title = title
        self.location = location
        self.salary = salary

    def display_info(self):
        return print(f"JOB:       {self.title}\nLOCATION:  {self.location}\nSALARY:    ${self.salary:,.0f}")

# %%
display_info("CEO","newyork",560)
# Out:
# JOB:       CEO
# LOCATION:  newyork
# SALARY:    $560

# %%
JobPost
# Out:
# __main__.JobPost

# %%
total_salary = 110000
bonus_salary = 1000

# %%
type(total_salary)
# Out:
# int

# %%
base_salary = total_salary - bonus_salary

# %%
base_salary
# Out:
# 109000

# %%
job_title = "data analyst"
remove_word = "data"

# %%
job_title
# Out:
# 'data analyst'

# %%
type(job_title)
# Out:
# str

# %%
final_title = job_title - remove_word # type: ignore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 final_title = job_title - remove_word # type: ignore
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
final_title = int(job_title) - int(remove_word)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 final_title = int(job_title) - int(remove_word)
#
# ValueError: invalid literal for int() with base 10: 'data analyst'

# %%
job_title = "data analyst"
remove_word = "data"
final_title = job_title.replace(remove_word, "").strip()
print(final_title)  # "data"
# Out:
# analyst

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
'data' + 'Nerd'
# Out:
# 'dataNerd'

# %%
'dataNerd'.capitalize()
# Out:
# 'Datanerd'

# %%
job_id = 102
type(job_id)
# Out:
# int

# %%
job_id = float(102)

# %%
type(job_id)
# Out:
# float

# %%
job_id
# Out:
# 102.0

# %%
skill = "python"
type(skill)
# Out:
# str

# %%
skill.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# #for string you can use double quote or single quote

# %%
skill.lower()
# Out:
# 'python'

# %%
help(str)

# %%
#replace("old","new",count=-1)by default -1 means replace all the occurrence
skill ="pythopnpep"
skill.replace("p","j",4)#4 occurence of p replaced
# Out:
# 'jythojnjej'

# %%
job_title = "data analyst" #rename data as doto
job_title.replace("a","o",2)
# Out:
# 'doto analyst'

# %%
job_title = job_title.replace("a","o",2)
job_title
# Out:
# 'doto onolyst'

# %%
job_title.split(sep=" ",maxsplit=2)
# Out:
# ['doto', 'onolyst']

# %%
job_title.split(" ",2)#it is not necessary to specify sep & maxsplit
# Out:
# ['doto', 'onolyst']

# %%
str.__add__("data"," analysteti")
# Out:
# 'data analysteti'

# %%
"data".__add__(" analystis")
# Out:
# 'data analystis'

# %%
"data analyst"* 10
# Out:
# 'data analystdata analystdata analystdata analystdata analystdata analystdata analystdata analystdata analystdata analyst'

# %%
"data analyst".__len__()

# %%
"ritajosephine".__len__()
# Out:
# 13

# %%
len("ritajosephine")
# Out:
# 13

# %%
job_title = "Data Analyst"
job_title.replace("a","o",count=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 job_title = "Data Analyst"
# ----> 2 job_title.replace("a","o",count=2)
#
# TypeError: str.replace() takes no keyword arguments

# %%
job_title = "Data Analyst"
new_title = job_title.replace("a", "o", 2)
print(new_title)
# Out:
# Doto Analyst
