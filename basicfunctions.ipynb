# %% [markdown]
# ### basic functions

# %%
skill_list = ['python', 'SQL','excel']
len(skill_list)
# Out:
# 3

# %% [markdown]
# type of function:
# built-in functions  print()
# user-defined functions def my_function():pass
# lambda functions   lambda x: x+ 1
# standard library functions math.sqrt()
# third party library functions  numpy.array()
#
# https://youtu.be/wUSDVGivd-8?t=10405

# %%
type(skill_list)
# Out:
# list

# %%
range(1, 5)
# Out:
# range(1, 5)

# %% [markdown]
# import types
# import builtins
# print([func for func in dir(__builtins__) if isinstance (getattr(__builtins__, func),types.BuiltinFunctionType)])not working see below why

# %% [markdown]
# import types
# builtins_module = __builtins__ if isinstance(__builtins__, types.ModuleType) else types.SimpleNamespace(**__builtins__)
# print([func for func in dir(builtins_module) if isinstance(getattr(builtins_module, func), types.BuiltinFunctionType)]) not working

# %%
import builtins, types
print([f for f in dir(builtins) if isinstance(getattr(builtins, f), types.BuiltinFunctionType)])
# Out:
# ['__build_class__', '__import__', 'abs', 'aiter', 'all', 'anext', 'any', 'ascii', 'bin', 'breakpoint', 'callable', 'chr', 'compile', 'delattr', 'dir', 'divmod', 'eval', 'exec', 'format', 'getattr', 'globals', 'hasattr', 'hash', 'hex', 'id', 'isinstance', 'issubclass', 'iter', 'len', 'locals', 'max', 'min', 'next', 'oct', 'open', 'ord', 'pow', 'print', 'repr', 'round', 'setattr', 'sorted', 'sum', 'vars']

# %% [markdown]
# Skip to content
# Chat history
#
#
# Upgrade your plan
# You said:
# import types
# print([func for func in dir(__builtins__) if isinstance (getattr(__builtins__, func),types.BuiltinFunctionType)]) why this code does not work when run no error given
# ChatGPT said:
# Good question — that’s actually a subtle one.
#
# ✅ Your code does work, but it only prints an empty list or prints nothing visible in some cases — that’s why it looks like it “does not work.”
#
# Let’s break it down:
#
# import types
# print([func for func in dir(__builtins__) if isinstance(getattr(__builtins__, func), types.BuiltinFunctionType)])
# 🔍 What this code does
# dir(__builtins__) → lists all names in the __builtins__ module (like 'len', 'print', 'sum', 'abs', etc.).
#
# getattr(__builtins__, func) → gets the actual object for each name.
#
# isinstance(..., types.BuiltinFunctionType) → checks if it’s a built-in function (like len, print, etc.).
#
# The list comprehension builds a list of those names.
#
# 🧩 Why you might “see nothing”
# If you’re in Jupyter or IPython, the builtins can be imported as a module or a dictionary.
# Try this:
#
# import builtins
# print([f for f in dir(builtins) if isinstance(getattr(builtins, f), types.BuiltinFunctionType)])
# That will definitely print a long list (like ['abs', 'all', 'any', 'ascii', 'bin', ...]).
#
# In some environments, __builtins__ is a dictionary, not a module.
# So getattr(__builtins__, func) won’t work, since dictionaries don’t have attributes.
#
# ✅ Fix:
#
# import types
# builtins_module = __builtins__ if isinstance(__builtins__, types.ModuleType) else types.SimpleNamespace(**__builtins__)
# print([func for func in dir(builtins_module) if isinstance(getattr(builtins_module, func), types.BuiltinFunctionType)])
# ✅ TL;DR Fix:
# Use this instead:
#
# import builtins, types
# print([f for f in dir(builtins) if isinstance(getattr(builtins, f), types.BuiltinFunctionType)])
# It will print something like:
#
# ['abs', 'all', 'any', 'ascii', 'bin', 'breakpoint', 'callable', ...]
# Would you like me to explain what types.BuiltinFunctionType actually represents under the hood?
#
#
#
#
# No file chosenNo file chosen
# ChatGPT can make mistakes. Check important info.

# %%
base_salary = 1000000
bonus_rate =0.1
def calculate_salary():
        base_salary = 1000000
        bonus_rate = 0.1
        total_salary = base_salary *(1 + bonus_rate)
        print(total_salary)

calculate_salary()
# Out:
# 1100000.0

# %%
base_salary = 1000000
bonus_rate =0.1
def calculate_salary():
        base_salary = 1000000
        bonus_rate = 0.1
        total_salary = base_salary *(1 + bonus_rate)
        return total_salary

calculate_salary()
# Out:
# 1100000.0

# %%
base_salary = 1000000
bonus_rate=0.1

def calculate_salary(base_salary, bonus_rate ):
       
        total_salary = base_salary *(1 + bonus_rate)
        return total_salary

calculate_salary(80000,0.2)
# Out:
# 96000.0

# %%
base_salary = 1000000

def calculate_salary(base_salary, bonus_rate =0.1 ):
       
        total_salary = base_salary *(1 + bonus_rate)
        return total_salary

calculate_salary(80000)
# Out:
# 88000.0

# %% [markdown]
# https://youtu.be/wUSDVGivd-8?t=10833

# %%
salary_1 = 100000
rate_1 = .5
calculate_salary(salary_1, rate_1)
# Out:
# 150000.0

# %% [markdown]
# basics Lambda
# https://youtu.be/wUSDVGivd-8?t=10926
# lambda x: x+1
# lambda argument : expression

# %%
mult_two=lambda x: x*2

# %%
mult_two(9)
# Out:
# 18

# %%
(lambda x: x*2)(3)
# Out:
# 6

# %%
(lambda x, y: x*2 + y)(3,4)
# Out:
# 10

# %%
salary_list = [100000, 20000, 150000,120000,8000,75000]
def calculate_salary(base_salary,bonus_rate=.1):
        total_salary = base_salary * (1+bonus_rate)
        return total_salary
total_salary_list = [salary for salary in salary_list]
total_salary_list
# Out:
# [100000, 20000, 150000, 120000, 8000, 75000]

# %%
salary_list = [100000, 20000, 150000,120000,8000,75000]
def calculate_salary(base_salary,bonus_rate=.1):
        total_salary = base_salary * (1+bonus_rate)
        return total_salary
total_salary_list = [calculate_salary(salary) for salary in salary_list]
total_salary_list
# Out:
# [110000.00000000001, 22000.0, 165000.0, 132000.0, 8800.0, 82500.0]

# %%
salary_list = [100000, 20000, 150000,120000,80000,75000]
# def calculate_salary(base_salary,bonus_rate=.1):
#         total_salary = base_salary * (1+bonus_rate)
#         return total_salary
total_salary_list = [(lambda x:x*.1) (salary)for salary in salary_list]
total_salary_list
# Out:
# [10000.0, 2000.0, 15000.0, 12000.0, 8000.0, 7500.0]

# %%
salary_list = [100000, 20000, 150000,120000,80000,75000]
# def calculate_salary(base_salary,bonus_rate=.1):
#         total_salary = base_salary * (1+bonus_rate)
#         return total_salary
total_salary_list = [salary* 1.1 for salary in salary_list]
total_salary_list
# Out:
# [110000.00000000001, 22000.0, 165000.0, 132000.0, 88000.0, 82500.0]

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
filter(lambda job: job['remote'],jobs_data)

# %%
print(filter(lambda job: job['remote'],jobs_data))

# %%
list(filter(lambda job: job['remote'],jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True},
#  {'job_title': 'Software Developer',
#   'job_skills': ['Java', 'C++'],
#   'remote': True}]

# %%
list(filter(lambda job: job['remote'] and "Python"in job ['job_skills'],jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True}]
