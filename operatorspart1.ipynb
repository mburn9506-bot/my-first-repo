# %% [markdown]
# #operators part1

# %% [markdown]
# https://youtu.be/wUSDVGivd-8

# %%
3 + 3
# Out:
# 6

# %%
2 + 3
print(2+3)
# Out:
# 5

# %%
"what's" + "up" +"!"

# %%
"what's up" * 10
# Out:
# "what's upwhat's upwhat's upwhat's upwhat's upwhat's upwhat's upwhat's upwhat's upwhat's up"

# %%
3.0 - 2
# Out:
# 1.0

# %%
"what's up" - "up"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 "what's up" - "up"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
four = 4
four.__sub__(2)
# Out:
# 2

# %%
4 -2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# #parentheses anything in parenthesis is executed first
# #exponents operation involving exponents (including roots,indicated as fractional exponents)
# #multiplication and division processed from left to right
# #addition and substraction also processed from left to right

# %%
print("5 divided by 2 is: ",5 // 2, " with a remainder of: ",5 % 2)
# Out:
# 5 divided by 2 is:  2  with a remainder of:  1

# %%
min_salary = 20_000 # this _ ignored by interpreter
max_salary = 80_000
avg_salary = (min_salary + max_salary) / 2
avg_salary
# Out:
# 50000.0

# %%
applicant_1 = "rita"
applicant_2 = "josephine"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_1 = temp_var

# %%
applicant_1, applicant_2
# Out:
# ('rita', 'josephine')

# %% [markdown]
# ### multiple values in one line

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('josephine', 'rita')

# %%
x = 1
x = x +1
x
# Out:
# 2

# %%
y = 1
y += 2
y
# Out:
# 3

# %%
z = 2
z *= 2
z
# Out:
# 4

# %%
salary_rita = 60_000
salary_joujou = 40_000

# %%
salary_rita == salary_joujou
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
if(salary_rita > salary_joujou):
        print('rita is paid more then joujou')
# Out:
# rita is paid more then joujou

# %% [markdown]
# ## basics Conditional :if , elif, else

# %%
if True:
        print("what's up data nerds")
# Out:
# what's up data nerds

# %%
if False:
        print("what's up data nerds")

# %%
if False:
        print("what's up data nerds")
else:
        print("not valid")
# Out:
# not valid

# %%
job_skill = 'SQL'
aplicant_skill = 'SQL'
if job_skill == aplicant_skill:
        print('skills matches')
# Out:
# skills matches

# %%
years_experience = 6
job_skill = 'SQL'
aplicant_skill = 'SQL'
if job_skill == aplicant_skill:
        print('skills matches')
elif years_experience >= 5:
        print("enough experience no SQL")
else:
        print("not enough")
# Out:
# skills matches

# %%
years_experience = 6
job_skill = 'SQL'
aplicant_skill = 'python'
if job_skill == aplicant_skill:
        print('skills matches')
elif years_experience >= 5:
        print("enough experience no SQL")
else:
        print("no skill or experience")
# Out:
# enough experience no SQL

# %%
years_experience = 3
job_skill = 'SQL'
aplicant_skill = 'python'
if job_skill == aplicant_skill:
        print('skills matches')
elif years_experience >= 5:
        print("enough experience no SQL")
else:
        print("no skill or experience")
# Out:
# no skill or experience

# %%
years_experience = 3
job_skill = 'python'
aplicant_skill = 'SQL'
if job_skill == aplicant_skill:
        print('skills matches')
elif years_experience >= 5:
        print("enough experience no SQL")
elif job_skill == 'python':
        print("this applicant should know SQL")
else:
        print("no skill or experience")
# Out:
# this applicant should know SQL
