# %% [markdown]
# #https://youtu.be/LTXnQdrwyrw?t=2

# %% [markdown]
# # dictionary:key-value pairs,unordered,mutable

# %% [markdown]
# mydict = {"name":"rita","age":28,"city":"newyork"}
# print(mydict)

# %% [markdown]
# print(dict)

# %% [markdown]
# mydict2 = dict(name="ritajosephine",age = 27,city="boston")
# print(mydict2)

# %% [markdown]
# value = mydict2["name"]
# print(value)
# value2 = mydict2["age"]
# print(value2)
# value3 = mydict2["city"]
# print(value3)

# %%
mydict2 = dict(name="ritajosephine",age = 27,city="boston")
mydict2["email"]="johnalain572.@gmail.com"
print(mydict2)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston', 'email': 'johnalain572.@gmail.com'}

# %%
mydict2 = dict(name="ritajosephine",age = 27,city="boston")
mydict2["email"]="cooljohnalain572.@gmail.com"
print(mydict2)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston', 'email': 'cooljohnalain572.@gmail.com'}

# %%
mydict2 = dict(name="ritajosephine",age = 27,city="boston")
mydict2["email"]="johnalain572.@gmail.com"
print(mydict2)
mydict2.pop("age")
print(mydict2)
del mydict2["name"]
print(mydict2)
del mydict2["email"]
print(mydict2)
mydict2.popitem()# remove the last key
print(mydict2)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston', 'email': 'johnalain572.@gmail.com'}
# {'name': 'ritajosephine', 'city': 'boston', 'email': 'johnalain572.@gmail.com'}
# {'city': 'boston', 'email': 'johnalain572.@gmail.com'}
# {'city': 'boston'}
# {}

# %% [markdown]
# https://youtu.be/LTXnQdrwyrw?t=271 continue

# %%
mydict = {"name":"ritajosephine","age" : 27,"city":"boston"}
print(mydict)
if "name" in mydict:
        print(mydict["name"])
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# ritajosephine

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
print(mydict)

if "name" in mydict:
    print(mydict["name"])  # ✅ correct way to print the value of "name"
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# ritajosephine

# %%
try:
        print(mydict["name"])
except:
        print("error")
# Out:
# ritajosephine

# %%
try:
        print(mydict["lastname"])
except:
        print("error")
# Out:
# error

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
print(mydict)
for key in mydict:#you can use "for key in mydict.keys()"
        print(key)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# name
# age
# city

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
print(mydict)
for value in mydict.values():
        print(value)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# ritajosephine
# 27
# boston

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
print(mydict)
for key,value in mydict.items():
        print(key, value)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# name ritajosephine
# age 27
# city boston

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
print(mydict)
mydict_cpy = mydict#you can use  "mydict_cpy = mydict.copy() or you can use also mydict_cpy = dict(mydict)"
print(mydict_cpy)
#if you modify the copy original will modify
mydict_cpy["email"]="johnalain@gmail.com"
print(mydict_cpy)
print(mydict)
# Out:
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston'}
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston', 'email': 'johnalain@gmail.com'}
# {'name': 'ritajosephine', 'age': 27, 'city': 'boston', 'email': 'johnalain@gmail.com'}

# %%
mydict = {"name": "ritajosephine", "age": 27, "city": "boston"}
my_dict_2 = {"name":"rita","age":28,"city":"paris","email":"john@gmail.com"}
mydict.update(my_dict_2)
print(mydict)
# Out:
# {'name': 'rita', 'age': 28, 'city': 'paris', 'email': 'john@gmail.com'}

# %%
mydict = {3:9,6:36,9:81}
print(mydict)
value = mydict[3]
print(value)
# Out:
# {3: 9, 6: 36, 9: 81}
# 9

# %%
mydict = {3:9,6:36,9:81}
print(mydict)
mytuple = (8,7)
mydict = {mytuple:15}
print(mydict)
# Out:
# {3: 9, 6: 36, 9: 81}
# {(8, 7): 15}
